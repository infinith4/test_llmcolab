# %% [markdown]
# <a href="https://colab.research.google.com/github/infinith4/test_llmcolab/blob/main/huggingface02_cosine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://so24.hatenablog.com/entry/2024/01/21/224029
#
# https://qiita.com/shimajiroxyz/items/705aca029ba1bc395df6
#
# https://tech.aru-zakki.com/mnist-metric-learning-faiss/

# %%
# !pip install sentence-transformers
# !pip install faiss-gpu
# !pip install fugashi
# !pip install ipadic
# !pip install langchain==0.0.304
# !pip install langchain-community==0.0.13
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 3.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import os
import pandas as pd
import numpy as np

from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain.vectorstores.utils import DistanceStrategy
from langchain_community.vectorstores import FAISS

# %%
sentences = ["明日の天気は晴れです", "明日の天気は雨です", "晴れが好きです"]
query = "次の日は良い天気です"

# %%
embeddings = HuggingFaceBgeEmbeddings(model_name ="sonoisa/sentence-bert-base-ja-mean-tokens-v2", encode_kwargs={"normalize_embeddings":True })
db = FAISS.from_texts(sentences, embeddings, distance_strategy = DistanceStrategy.MAX_INNER_PRODUCT)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/667 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/258k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
docs_and_scores = db.similarity_search_with_score(query)
docs_and_scores
# Out:
# [(Document(page_content='明日の天気は晴れです'), 0.5200572),
#  (Document(page_content='晴れが好きです'), 0.49400553),
#  (Document(page_content='明日の天気は雨です'), 0.39415574)]

# %%
print(docs_and_scores[0][0])
print(docs_and_scores[0][1])
# Out:
# page_content='明日の天気は晴れです'
# 0.5200572

# %%
db.save_local("faiss_index")

# %%
new_db = FAISS.load_local("faiss_index", embeddings)

# %%
#再度計算
docs_and_scores = new_db.similarity_search_with_score(query)
print(docs_and_scores[0][0])
print(docs_and_scores[0][1])
# Out:
# page_content='明日の天気は晴れです'
# 0.5200572
